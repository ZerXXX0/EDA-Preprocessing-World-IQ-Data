# %% [markdown]
# <a href="https://colab.research.google.com/github/ZerXXX0/EDA-Preprocessing-World-IQ-Data/blob/main/World_iq_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import
import statistics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ZerXXX0/EDA-Preprocessing-World-IQ-Data/main/avgIQpercountry.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#    Rank    Country  Average IQ Continent  Literacy Rate  Nobel Prices  \
# 0     1      Japan      106.48      Asia           0.99            29
# 1     2     Taiwan      106.47      Asia           0.96             4
# 2     3  Singapore      105.89      Asia           0.97             0
# 3     4  Hong Kong      105.37      Asia           0.94             1
# 4     5      China      104.10      Asia           0.96             8
#
#    HDI (2021)  Mean years of schooling - 2021   GNI - 2021 Population - 2023
# 0       0.925                            13.4        42274         123294513
# 1       0.926                            13.9        67000          10143543
# 2       0.939                            11.9        90919           6014723
# 3       0.952                            12.2        62607           7491609
# 4       0.768                             7.6        17504        1425671352

# %%
df.describe()
# Out:
#              Rank  Average IQ  Literacy Rate  Nobel Prices  HDI (2021)  \
# count  193.000000  193.000000     193.000000    193.000000  193.000000
# mean    97.000000   82.047927       0.864249      5.922280    0.729301
# std     55.858452   13.336117       0.180262     31.971328    0.155203
# min      1.000000   42.990000       0.190000      0.000000    0.361000
# 25%     49.000000   74.330000       0.800000      0.000000    0.607000
# 50%     97.000000   82.240000       0.950000      0.000000    0.751000
# 75%    145.000000   91.600000       0.990000      1.000000    0.855000
# max    193.000000  106.480000       1.000000    400.000000    0.981000
#
#        Mean years of schooling - 2021     GNI - 2021
# count                      193.000000     193.000000
# mean                         9.064663   21227.777202
# std                          3.091836   23327.037018
# min                          2.100000     600.000000
# 25%                          7.000000    4548.000000
# 50%                          9.200000   12672.000000
# 75%                         11.400000   30690.000000
# max                         14.100000  146830.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            193 non-null    int64
#  1   Country                         193 non-null    object
#  2   Average IQ                      193 non-null    float64
#  3   Continent                       193 non-null    object
#  4   Literacy Rate                   193 non-null    float64
#  5   Nobel Prices                    193 non-null    int64
#  6   HDI (2021)                      193 non-null    float64
#  7   Mean years of schooling - 2021  193 non-null    float64
#  8    GNI - 2021                     193 non-null    int64
#  9   Population - 2023               193 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 15.2+ KB

# %%
sns.pairplot(df, hue='Average IQ')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Average IQ'],bins=20,kde=True)
plt.title("Histogram")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Continent', y='Average IQ')
plt.title("Boxplot")
plt.show()

# %%
correlation_matrix = df[['Average IQ','HDI (2021)']].corr()
print(correlation_matrix)
# Out:
#             Average IQ  HDI (2021)
# Average IQ    1.000000    0.743239
# HDI (2021)    0.743239    1.000000

# %%
correlation_matrix1 = df[['Average IQ',' GNI - 2021']].corr()
print(correlation_matrix1)
# Out:
#              Average IQ   GNI - 2021
# Average IQ     1.000000     0.613087
#  GNI - 2021    0.613087     1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Heatmap Correlation")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix1, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Heatmap Correlation")
plt.show()
